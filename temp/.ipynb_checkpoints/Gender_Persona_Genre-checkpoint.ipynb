# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file into a DataFrame
file_path = "../Data/Persona/movies_char_personas.csv"  # Replace with the actual path to your CSV file
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame to understand its structure
#print(df.head())

# Replace NaN values in "Actor Gender" column with a placeholder (e.g., 'Unknown')
df['Actor gender'].fillna('Unknown', inplace=True)

# Analyze the relationship between "Persona_code" and "Actor Gender"
persona_gender_counts = df.groupby(['Persona_code', 'Actor gender']).size().unstack()

# Display the top 10 personas for male and female actors
top_male_personas = persona_gender_counts['M'].nlargest(10)
top_female_personas = persona_gender_counts['F'].nlargest(10)

#print("Top 10 Personas for Male Actors:")
#print(top_male_personas)

#print("\nTop 10 Personas for Female Actors:")
#print(top_female_personas)


# Combine the top personas for both male and female actors
combined_top_personas = pd.concat([top_male_personas, top_female_personas], axis=1, keys=['Male', 'Female'])

# Visualize the results in a grouped bar plot
fig, ax = plt.subplots(figsize=(12, 8))

combined_top_personas.plot(kind='bar', ax=ax, width=0.8)

ax.set_title('Top 10 Personas for Male and Female Actors')
ax.set_ylabel('Count')
ax.set_xlabel('Persona Code')

plt.show()

# %%
# Calculate the total number of male and female actors
total_male_actors = df[df['Actor gender'] == 'M'].shape[0]
total_female_actors = df[df['Actor gender'] == 'F'].shape[0]

# Analyze the relationship between "Persona_code" and "Actor Gender"
persona_gender_counts = df.groupby(['Persona_code', 'Actor gender']).size().unstack()

# Calculate the percentages for each persona separately
persona_gender_percentages_male = persona_gender_counts['M'] / total_male_actors * 100
persona_gender_percentages_female = persona_gender_counts['F'] / total_female_actors * 100

# Combine the percentages for both male and female actors
combined_percentages = pd.concat([persona_gender_percentages_male, persona_gender_percentages_female], axis=1, keys=['Male', 'Female'])

# Visualize the results in a grouped bar plot
fig, ax = plt.subplots(figsize=(10, 5))

combined_percentages.plot(kind='bar', ax=ax, width=0.8)

ax.set_title('Top Personas for Male and Female Actors (Percentage)')
ax.set_ylabel('Percentage')
ax.set_xlabel('Persona Code')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file with characters' personas
characters_file_path = "../Data/Persona/movies_char_personas.csv" 
characters_df = pd.read_csv(characters_file_path)
sample_ch_df = characters_df.head(10000)

# Load the TSV file with movie metadata and provide column names
metadata_file_path = "../Data/movie.metadata.tsv"
metadata_columns = ['Wikipedia Movie ID', 'Freebase Movie ID', 'Movie name', 'Movie Release Data', 'Movie Box Office Revenue', 'Movie runtime', 'Movie languages', 'Movie countries','Movie_Genre']
metadata_df = pd.read_csv(metadata_file_path, sep='\t', header=None, names=metadata_columns)
sample_meta_df = metadata_df.head(10000)

#display(metadata_df)

# Merge dataframes based on "Freebase Movie ID"
merged_df = pd.merge(sample_ch_df, sample_meta_df, on="Freebase Movie ID", how="inner")

# Replace NaN values in "Actor Gender" column with a placeholder (e.g., 'Unknown')
merged_df['Actor gender'].fillna('Unknown', inplace=True)

# Split the genres in the "Movie Genre" column
merged_df['Movie_Genre'] = merged_df['Movie_Genre'].str.split(',')

# Create a new dataframe with one row for each genre of each movie
expanded_genre_df = merged_df.explode('Movie_Genre')

# Identify the top 25 genres
top_genres = expanded_genre_df['Movie_Genre'].value_counts().nlargest(25).index

# Iterate through each genre and show the top 10 personas
for genre in top_genres:
    genre_df = expanded_genre_df[expanded_genre_df['Movie_Genre'] == genre]
    persona_counts = genre_df['Persona_code'].value_counts().nlargest(10)
    
    print(f"\nTop 10 Personas for {genre}:")
    print(persona_counts)
# Out:
# Top 10 Personas for  "/m/07s9rl0": "Drama":
# 10    59
# 35    53
# 47    46
# 43    35
# 3     27
# 24    21
# 23    21
# 5     18
# 45    11
# 26    10
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/01z4y": "Comedy":
# 10    42
# 3     37
# 33    22
# 47    17
# 35    12
# 17    11
# 40     9
# 45     7
# 16     6
# 22     6
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for {"/m/01jfsb": "Thriller":
# 47    36
# 0     24
# 23    24
# 17    23
# 40    19
# 5     12
# 1     10
# 33     9
# 27     7
# 6      6
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/02l7c8": "Romance Film":
# 10    42
# 43    20
# 47    12
# 35    10
# 33     7
# 45     5
# 3      4
# 18     3
# 20     3
# 23     3
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/01z4y": "Comedy"}:
# 10    43
# 3     15
# 43    15
# 47    11
# 16     8
# 35     7
# 33     7
# 2      4
# 40     3
# 0      2
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/02kdv5l": "Action":
# 47    40
# 5     23
# 33     8
# 24     7
# 6      5
# 40     5
# 27     5
# 3      4
# 13     3
# 23     3
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/03btsm8": "Action/Adventure":
# 5     19
# 47    15
# 40    12
# 17     9
# 33     8
# 6      7
# 13     6
# 24     6
# 23     5
# 3      5
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/01hmnh": "Fantasy":
# 33    24
# 40    18
# 5     11
# 35     7
# 10     5
# 1      4
# 3      4
# 16     4
# 20     3
# 49     3
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/03npn": "Horror":
# 17    40
# 0     14
# 40     9
# 23     8
# 6      6
# 1      5
# 33     3
# 30     2
# 36     2
# 38     2
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/02n4kr": "Mystery":
# 0     17
# 47    16
# 23    13
# 35     6
# 1      6
# 17     5
# 33     5
# 38     4
# 32     3
# 36     2
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/0hqxf": "Family Film":
# 33    24
# 2     12
# 40    11
# 3      4
# 24     4
# 49     3
# 45     3
# 16     3
# 43     3
# 1      3
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/068d7h": "Romantic drama":
# 10    26
# 43    13
# 35    12
# 24     8
# 45     5
# 18     3
# 23     3
# 47     3
# 26     2
# 48     2
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/04xvlr": "Period piece":
# 10    25
# 35    12
# 24     6
# 3      5
# 5      4
# 22     4
# 0      3
# 23     3
# 31     3
# 45     3
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for {"/m/0lsxr": "Crime Fiction":
# 47    25
# 23     7
# 10     6
# 3      5
# 38     4
# 31     4
# 35     3
# 45     2
# 40     2
# 34     2
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/03q4nz": "World cinema"}:
# 43    18
# 35    18
# 18    10
# 47     6
# 45     6
# 23     3
# 49     2
# 37     2
# 46     2
# 26     2
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/03k9fj": "Adventure":
# 5     18
# 40    16
# 33    15
# 24     5
# 47     4
# 3      3
# 1      3
# 0      2
# 6      2
# 20     2
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for {"/m/06cvj": "Romantic comedy":
# 10    46
# 43    10
# 35     4
# 3      3
# 33     2
# 45     2
# 20     1
# 26     1
# 36     1
# 39     1
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/02l7c8": "Romance Film"}:
# 10    28
# 35    12
# 24     7
# 43     5
# 45     3
# 3      3
# 18     2
# 26     2
# 0      1
# 48     1
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/02kdv5l": "Action"}:
# 40    17
# 33     8
# 17     7
# 5      6
# 13     4
# 20     4
# 47     3
# 6      3
# 15     3
# 27     2
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/060__y": "Film adaptation":
# 10    17
# 5     11
# 35     7
# 47     6
# 3      4
# 49     3
# 23     3
# 28     2
# 40     2
# 33     2
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for {"/m/07s9rl0": "Drama":
# 35    15
# 10    11
# 24    10
# 18     5
# 47     4
# 43     4
# 45     3
# 13     2
# 33     2
# 1      1
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/04t36": "Musical":
# 10    15
# 43    14
# 33     6
# 24     4
# 26     3
# 49     2
# 39     2
# 3      2
# 35     1
# 48     1
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/09blyk": "Psychological thriller":
# 17    14
# 0      9
# 47     9
# 23     8
# 1      4
# 35     4
# 36     4
# 30     2
# 6      1
# 10     1
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/07s9rl0": "Drama"}:
# 35    10
# 10    10
# 45     7
# 47     6
# 43     3
# 39     3
# 31     3
# 24     2
# 28     2
# 37     2
# Name: Persona_code, dtype: int64
#
# Top 10 Personas for  "/m/01j1n2": "Coming of age":
# 10    10
# 3     10
# 33     6
# 35     5
# 13     4
# 49     3
# 45     3
# 24     3
# 6      2
# 20     2
# Name: Persona_code, dtype: int64

# %%
# Iterate through each persona and show the top 5 genres
persona_list = merged_df['Persona_code'].unique()

for persona in persona_list:
    persona_df = merged_df[merged_df['Persona_code'] == persona]
    genre_counts = persona_df['Movie_Genre'].explode().value_counts().nlargest(5)
    
    print(f"\nTop 5 Genres for Persona {persona}:")
    print(genre_counts)
# Out:
# Top 5 Genres for Persona 47:
#  "/m/07s9rl0": "Drama"          46
#  "/m/02kdv5l": "Action"         40
# {"/m/01jfsb": "Thriller"        36
# {"/m/0lsxr": "Crime Fiction"    25
#  "/m/01z4y": "Comedy"           17
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 34:
#  "/m/07s9rl0": "Drama"           3
#  "/m/082gq": "War film"          2
# {"/m/01jfsb": "Thriller"         2
# {"/m/0lsxr": "Crime Fiction"     2
#  "/m/02h8pkk": "Family Drama"    1
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 5:
#  "/m/02kdv5l": "Action"              23
#  "/m/03btsm8": "Action/Adventure"    19
#  "/m/03k9fj": "Adventure"            18
#  "/m/07s9rl0": "Drama"               18
#  "/m/06l3bl": "Epic"                 12
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 33:
#  "/m/0hqxf": "Family Film"    24
#  "/m/01hmnh": "Fantasy"       24
#  "/m/01z4y": "Comedy"         22
# {"/m/03k9fj": "Adventure"     18
#  "/m/0hcr": "Animation"       17
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 24:
#  "/m/07s9rl0": "Drama"            21
# {"/m/07s9rl0": "Drama"            10
#  "/m/068d7h": "Romantic drama"     8
#  "/m/02kdv5l": "Action"            7
#  "/m/082gq": "War film"            7
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 6:
#  "/m/03btsm8": "Action/Adventure"    7
# {"/m/01jfsb": "Thriller"             6
#  "/m/03npn": "Horror"                6
#  "/m/07s9rl0": "Drama"               5
#  "/m/02kdv5l": "Action"              5
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 26:
#  "/m/07s9rl0": "Drama"      10
# {"/m/01jfsb": "Thriller"     4
#  "/m/04t36": "Musical"       3
#  "/m/01z4y": "Comedy"        3
# {"/m/02kdv5l": "Action"}     2
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 45:
#  "/m/07s9rl0": "Drama"            11
#  "/m/07s9rl0": "Drama"}            7
#  "/m/01z4y": "Comedy"              7
#  "/m/03q4nz": "World cinema"}      6
#  "/m/068d7h": "Romantic drama"     5
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 46:
#  "/m/07s9rl0": "Drama"               3
#  "/m/0hj3mz5": "Comedy of Errors"    2
# {"/m/0556j8": "Buddy film"           2
#  "/m/09q17": "Slapstick"}            2
#  "/m/01z4y": "Comedy"                2
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 0:
# {"/m/01jfsb": "Thriller"                  24
#  "/m/02n4kr": "Mystery"                   17
#  "/m/03npn": "Horror"                     14
#  "/m/09blyk": "Psychological thriller"     9
#  "/m/0fdjb": "Supernatural"                9
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 1:
# {"/m/01jfsb": "Thriller"    10
#  "/m/07s9rl0": "Drama"       8
#  "/m/02n4kr": "Mystery"      6
#  "/m/02n4kr": "Mystery"}     5
#  "/m/03npn": "Horror"        5
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 40:
# {"/m/01jfsb": "Thriller"          19
#  "/m/01hmnh": "Fantasy"           18
#  "/m/02kdv5l": "Action"}          17
#  "/m/03k9fj": "Adventure"         16
#  "/m/06n90": "Science Fiction"    14
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 20:
#  "/m/07s9rl0": "Drama"               6
#  "/m/01z4y": "Comedy"                4
#  "/m/02kdv5l": "Action"}             4
#  "/m/01hmnh": "Fantasy"              3
#  "/m/03btsm8": "Action/Adventure"    3
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 10:
#  "/m/07s9rl0": "Drama"            59
# {"/m/06cvj": "Romantic comedy"    46
#  "/m/01z4y": "Comedy"}            43
#  "/m/02l7c8": "Romance Film"      42
#  "/m/01z4y": "Comedy"             42
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 43:
#  "/m/07s9rl0": "Drama"           35
#  "/m/02l7c8": "Romance Film"     20
#  "/m/03q4nz": "World cinema"}    18
#  "/m/01z4y": "Comedy"}           15
#  "/m/04t36": "Musical"           14
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 18:
#  "/m/03q4nz": "World cinema"}     10
#  "/m/07s9rl0": "Drama"             8
#  "/m/01chg": "Bollywood"           6
# {"/m/07s9rl0": "Drama"             5
#  "/m/068d7h": "Romantic drama"     3
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 28:
#  "/m/01t_vv": "Comedy-drama"       3
#  "/m/01z4y": "Comedy"              3
#  "/m/07s9rl0": "Drama"}            2
#  "/m/060__y": "Film adaptation"    2
#  "/m/01j1n2": "Coming of age"      2
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 35:
#  "/m/07s9rl0": "Drama"           53
#  "/m/03q4nz": "World cinema"}    18
# {"/m/07s9rl0": "Drama"           15
#  "/m/02h8pkk": "Family Drama"    15
#  "/m/02l7c8": "Romance Film"}    12
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 27:
#  "/m/07s9rl0": "Drama"              9
# {"/m/01jfsb": "Thriller"            7
#  "/m/01jfsb": "Thriller"            5
#  "/m/02kdv5l": "Action"             5
#  "/m/04t2t": "Martial Arts Film"    3
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 37:
#  "/m/07s9rl0": "Drama"               8
#  "/m/03q4nz": "World cinema"         3
# {"/m/06n90": "Science Fiction"       3
#  "/m/03btsm8": "Action/Adventure"    3
#  "/m/082gq": "War film"              3
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 11:
#  "/m/0hj3mws": "Biopic [feature]"    3
#  "/m/03bxz7": "Biographical film"    3
#  "/m/0hj3n1c": "Escape Film"         3
#  "/m/0lsxr": "Crime Fiction"         3
#  "/m/0hn10": "LGBT"                  3
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 31:
#  "/m/07s9rl0": "Drama"          9
#  "/m/01z4y": "Comedy"           4
# {"/m/0lsxr": "Crime Fiction"    4
#  "/m/04xvlr": "Period piece"    3
#  "/m/07s9rl0": "Drama"}         3
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 13:
#  "/m/03btsm8": "Action/Adventure"    6
#  "/m/04t2t": "Martial Arts Film"     5
#  "/m/0gw5qqq": "Chinese Movies"}     4
#  "/m/02kdv5l": "Action"}             4
#  "/m/01j1n2": "Coming of age"        4
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 44:
# {"/m/01jfsb": "Thriller"                  2
#  "/m/03k9fj": "Adventure"                 2
#  "/m/03btsm8": "Action/Adventure"         1
#  "/m/09blyk": "Psychological thriller"    1
#  "/m/0hj3n2s": "Fantasy Comedy"           1
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 3:
#  "/m/01z4y": "Comedy"            37
#  "/m/07s9rl0": "Drama"           27
# {"/m/01z02hx": "Sports"          16
#  "/m/01z4y": "Comedy"}           15
#  "/m/01j1n2": "Coming of age"    10
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 39:
#  "/m/07s9rl0": "Drama"          5
#  "/m/07s9rl0": "Drama"}         3
#  "/m/01z4y": "Comedy"           3
#  "/m/01t_vv": "Comedy-drama"    2
# {"/m/02l7c8": "Romance Film"    2
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 49:
#  "/m/07s9rl0": "Drama"             6
#  "/m/060__y": "Film adaptation"    3
#  "/m/01hmnh": "Fantasy"            3
#  "/m/01j1n2": "Coming of age"      3
#  "/m/0hqxf": "Family Film"         3
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 32:
#  "/m/02n4kr": "Mystery"               3
# {"/m/01jfsb": "Thriller"              2
#  "/m/0hqxf": "Family Film"            1
#  "/m/0hj3n2s": "Fantasy Comedy"       1
#  "/m/0hj3myq": "Children's/Family"    1
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 2:
# {"/m/02hmvc": "Short Film"     18
#  "/m/0hcr": "Animation"}       13
#  "/m/0hqxf": "Family Film"     12
#  "/m/05p553": "Comedy film"     7
#  "/m/01z4y": "Comedy"           5
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 48:
#  "/m/03g3w": "History"               3
#  "/m/07s9rl0": "Drama"               3
#  "/m/04xvlr": "Period piece"         2
#  "/m/068d7h": "Romantic drama"       2
# {"/m/03p5xs": "Comedy of manners"    1
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 16:
#  "/m/01z4y": "Comedy"}             8
# {"/m/0hqxf": "Family Film"         6
#  "/m/01z4y": "Comedy"              6
#  "/m/01hmnh": "Fantasy"            4
#  "/m/0hj3n2s": "Fantasy Comedy"    3
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 17:
#  "/m/03npn": "Horror"                     40
# {"/m/01jfsb": "Thriller"                  23
#  "/m/01q03": "Cult"                       19
#  "/m/09blyk": "Psychological thriller"    14
#  "/m/06n90": "Science Fiction"            14
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 41:
#  "/m/0hj3n62": "Heavenly Comedy"        1
# {"/m/0hj3myq": "Children's/Family"      1
#  "/m/01z4y": "Comedy"                   1
#  "/m/0hj3n6r": "Holiday Film"           1
#  "/m/0hj3myc": "Children's Fantasy"}    1
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 23:
# {"/m/01jfsb": "Thriller"                  24
#  "/m/07s9rl0": "Drama"                    21
#  "/m/02n4kr": "Mystery"                   13
#  "/m/09blyk": "Psychological thriller"     8
#  "/m/03npn": "Horror"                      8
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 42:
#  "/m/07s9rl0": "Drama"               4
#  "/m/01z4y": "Comedy"                2
# {"/m/03p5xs": "Comedy of manners"    2
#  "/m/0hj3n0k": "Domestic Comedy"}    2
# {"/m/04p5fxn": "Christian film"      1
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 21:
#  "/m/01hmnh": "Fantasy"              2
#  "/m/06n90": "Science Fiction"       2
#  "/m/04pbhw": "Superhero movie"}     2
#  "/m/02kdv5l": "Action"              2
# {"/m/03btsm8": "Action/Adventure"    2
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 30:
#  "/m/01q03": "Cult"               2
# {"/m/06n90": "Science Fiction"    2
#  "/m/0219x_": "Indie"}            2
#  "/m/03npn": "Horror"             2
#  "/m/06nbt": "Satire"             2
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 38:
#  "/m/028v3": "Detective fiction"    4
#  "/m/0c3351": "Suspense"            4
#  "/m/07s9rl0": "Drama"              4
# {"/m/0lsxr": "Crime Fiction"        4
#  "/m/0j5nm": "Whodunit"}            4
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 36:
# {"/m/01jfsb": "Thriller"                  5
#  "/m/09blyk": "Psychological thriller"    4
#  "/m/01z4y": "Comedy"                     3
#  "/m/07s9rl0": "Drama"                    3
#  "/m/02n4kr": "Mystery"                   2
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 22:
#  "/m/01z4y": "Comedy"               6
#  "/m/04xvlr": "Period piece"        4
#  "/m/082gq": "War film"}            4
# {"/m/0gf28": "Parody"               4
#  "/m/01lmb_": "Sword and Sandal"    4
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 9:
#  "/m/05swd": "Propaganda film"      1
#  "/m/0hj3mry": "Addiction Drama"    1
#  "/m/01g6gs": "Black-and-white"}    1
#  "/m/02b5_l": "Teen"                1
# {"/m/0lsxr": "Crime Fiction"        1
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 19:
#  "/m/01hmnh": "Fantasy"            1
#  "/m/060__y": "Film adaptation"    1
#  "/m/01j1n2": "Coming of age"      1
#  "/m/04t36": "Musical"             1
#  "/m/07s9rl0": "Drama"             1
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 15:
#  "/m/03btsm8": "Action/Adventure"    3
#  "/m/01hwc6": "Absurdism"            3
#  "/m/01drsx": "Disaster"             3
#  "/m/02kdv5l": "Action"}             3
# {"/m/0gf28": "Parody"                3
# Name: Movie_Genre, dtype: int64
#
# Top 5 Genres for Persona 12:
#  "/m/03btsm8": "Action/Adventure"    1
#  "/m/01hwc6": "Absurdism"            1
#  "/m/01drsx": "Disaster"             1
#  "/m/02kdv5l": "Action"}             1
# {"/m/0gf28": "Parody"                1
# Name: Movie_Genre, dtype: int64

# %%
import networkx as nx

# Identify the top 20 personas and genres
top_personas = merged_df['Persona_code'].value_counts().nlargest(20).index
top_genres = expanded_genre_df['Movie_Genre'].value_counts().nlargest(20).index

# Filter dataframes to include only the top 20 personas and genres
filtered_persona_df = merged_df[merged_df['Persona_code'].isin(top_personas)]
filtered_genre_df = expanded_genre_df[expanded_genre_df['Movie_Genre'].isin(top_genres)]

# Create a weighted bipartite graph
B = nx.Graph()

# Add nodes for top 20 personas and top 20 genres
B.add_nodes_from(top_personas, bipartite=0, label='Persona')
B.add_nodes_from(top_genres, bipartite=1, label='Genre')

# Convert lists in 'Movie Genre' to tuples for edge creation
filtered_persona_df['Movie_Genre'] = filtered_persona_df['Movie_Genre'].apply(tuple)

# Create edges with real counts as weights
edges = filtered_persona_df.groupby(['Persona_code', 'Movie_Genre']).size().reset_index(name='count')
for row in edges.itertuples(index=False):
    B.add_edge(row.Persona_code, row.Movie_Genre, weight=row.count)

# Draw the bipartite graph with automatic layout
plt.figure(figsize=(12, 8))
pos = nx.bipartite_layout(B, top_personas)
nx.draw(B, pos, with_labels=True, font_size=8, node_size=500, node_color='skyblue', font_color='black', font_weight='bold')
edge_labels = nx.get_edge_attributes(B, 'weight')
nx.draw_networkx_edge_labels(B, pos, edge_labels=edge_labels)
plt.title('Weighted Bipartite Graph of Top 20 Personas and Top 20 Genres')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
